# %% [markdown]
# <a href="https://colab.research.google.com/github/talpt/pyton/blob/main/maestro_alpha_trend_signal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Kütüphaneler
# !pip install git+https://github.com/rongardF/tvdatafeed backtesting
# !pip install tradingview-screener==2.5.0

import pandas as pd
import numpy as np
from tvDatafeed import TvDatafeed, Interval
from tradingview_screener import get_all_symbols
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning, module="backtesting")

# Zaman dilimi ismini döndürme fonksiyonu
def interval_name(interval):
    interval_map = {
        Interval.in_15_minute: '15 Dakika',
        Interval.in_30_minute: '30 Dakika',
        Interval.in_45_minute: '45 Dakika',
        Interval.in_1_hour: '1 Saat',
        Interval.in_2_hour: '2 Saat',
        Interval.in_4_hour: '4 Saat',
        Interval.in_daily: 'Günlük',
        Interval.in_weekly: 'Haftalık',
        Interval.in_monthly: 'Aylık'
    }
    return interval_map.get(interval, 'Günlük')

# Kullanıcının zaman dilimini seçmesini sağlayan fonksiyon
def get_interval_choice():
    intervals = {
        '1': ('15 Dakika', Interval.in_15_minute),
        '2': ('30 Dakika', Interval.in_30_minute),
        '3': ('45 Dakika', Interval.in_45_minute),
        '4': ('1 Saat', Interval.in_1_hour),
        '5': ('2 Saat', Interval.in_2_hour),
        '6': ('4 Saat', Interval.in_4_hour),
        '7': ('Günlük', Interval.in_daily),
        '8': ('Haftalık', Interval.in_weekly),
        '9': ('Aylık', Interval.in_monthly)
    }

    print("Lütfen zaman dilimini seçin:")
    for key, (name, _) in intervals.items():
        print(f"{key}. {name}")

    choice = input("Seçiminiz (örnek: 6): ").strip()
    return intervals.get(choice, ('Günlük', Interval.in_daily))

# Standart Moving Average
def sma(series, length):
    return series.rolling(window=length).mean()

def mfi(high, low, close, volume, window=14):
    typical_price = (high + low + close) / 3
    money_flow = typical_price * volume
    positive_money_flow = (money_flow * (close > close.shift(1))).rolling(window=window).sum()
    negative_money_flow = (money_flow * (close < close.shift(1))).rolling(window=window).sum()
    money_ratio = positive_money_flow / negative_money_flow
    mfi = 100 - (100 / (1 + money_ratio))
    return mfi

def tr(high, low, close):
    tr1 = high - low
    tr2 = abs(high - close.shift(1))
    tr3 = abs(low - close.shift(1))
    tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
    return tr

def Alpha_Trend(df, mult=1, n1=14):
    df['TR'] = tr(df['High'], df['Low'], df['Close'])
    df['ATR'] = sma(df['TR'], length=n1)
    df['mfi'] = mfi(df['High'], df['Low'], df['Close'], df['Volume'], n1)
    df['upT'] = df['Low'] - df['ATR'] * mult
    df['downT'] = df['High'] + df['ATR'] * mult
    df['AlphaTrend'] = 0.0
    alpha_trend_values = [0.0]

    for i in range(1, len(df)):
        if df['mfi'].iloc[i] >= 50:
            alpha_trend_values.append(max(df['upT'].iloc[i], alpha_trend_values[i-1]))
        else:
            alpha_trend_values.append(min(df['downT'].iloc[i], alpha_trend_values[i-1]))

    df['AlphaTrend'] = alpha_trend_values
    df['Entry'] = False
    prev_signal = False
    for i in range(2, len(df)):
        if df.loc[i, 'AlphaTrend'] > df.loc[i-2, 'AlphaTrend']:
            df.loc[i, 'Entry'] = True
            prev_signal = True
        elif df.loc[i, 'AlphaTrend'] == df.loc[i-2, 'AlphaTrend'] and prev_signal:
            df.loc[i, 'Entry'] = True
        else:
            prev_signal = False
    df['Exit'] = df['Entry'] == False
    return df

# Kullanıcıdan zaman dilimi al
selected_name, selected_interval = get_interval_choice()
print(f"Seçilen Zaman Dilimi: {selected_name}")

tv = TvDatafeed()
Hisseler = get_all_symbols(market='turkey')
Hisseler = [symbol.replace('BIST:', '') for symbol in Hisseler]
Hisseler = sorted(Hisseler)

# Raporlama için kullanılacak başlıklar
Titles = ['Hisse Adı', 'Son Fiyat', 'Kazanma Oranı', 'Giriş Sinyali', 'Çıkış Sinyali']

df_signals = pd.DataFrame(columns=Titles)

# Backtest için gerekli class yapısı
from backtesting import Backtest, Strategy

class MyStrategy(Strategy):
    def init(self):
        pass

    def next(self):
        if self.data['Entry'] == True and not self.position:
            self.buy()
        elif self.data['Exit'] == True:
            self.position.close()

# Hisse verilerini çekme ve analiz etme
for i in range(0, len(Hisseler)):
    try:
        mult = 1
        n1 = 14
        # Zaman dilimi parametresini seçilen interval ile değiştir
        data = tv.get_hist(symbol=Hisseler[i], exchange='BIST', interval=selected_interval, n_bars=500)
        data.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'}, inplace=True)
        data = data.reset_index()
        AlphaTrend = Alpha_Trend(data, mult, n1)
        AlphaTrend['datetime'] = pd.to_datetime(AlphaTrend['datetime'])
        AlphaTrend.set_index('datetime', inplace=True)
        bt = Backtest(AlphaTrend, MyStrategy, cash=100000, commission=0.002)
        Stats = bt.run()
        Buy = False
        Sell = False
        Signals = AlphaTrend.tail(2)
        Signals = Signals.reset_index()
        Buy = Signals.loc[0, 'Entry'] == False and Signals.loc[1, 'Entry'] == True
        Sell = Signals.loc[0, 'Exit'] == False and Signals.loc[1, 'Exit'] == True
        Last_Price = Signals.loc[1, 'Close']
        L1 = [Hisseler[i], Last_Price, round(Stats.loc['Win Rate [%]'], 2), str(Buy), str(Sell)]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except:
        pass

# Giriş sinyali olan hisse senetlerini yazdır
df_True = df_signals[(df_signals['Giriş Sinyali'] == 'True')]
print(df_True.to_string())
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-63aq_wk1
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-63aq_wk1
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Collecting backtesting
#   Downloading Backtesting-0.3.3.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tvdatafeed==2.1.0) (75.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tvdatafeed==2.1.0) (2.2.2)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from tvdatafeed==2.1.0) (2.32.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from backtesting) (1.26.4)
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from backtesting) (3.6.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from bokeh>=1.4.0->backtesting) (3.1.5)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=1.4.0->backtesting) (1.3.1)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.11/dist-packages (from bokeh>=1.4.0->backtesting) (24.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from bokeh>=1.4.0->backtesting) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh>=1.4.0->backtesting) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=1.4.0->backtesting) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/dist-packages (from bokeh>=1.4.0->backtesting) (2024.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->tvdatafeed==2.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->tvdatafeed==2.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->tvdatafeed==2.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->tvdatafeed==2.1.0) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->backtesting) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.17.0)
# Building wheels for collected packages: tvdatafeed, backtesting
#   Building wheel for tvdatafeed (setup.py) ... done
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17533 sha256=e4067467ab056ad532c51dcf413b9f0e4538917e91e1e3458a4939285016d7c7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6livj5t1/wheels/0a/ba/99/b27476fd1e4caf0dd70445cdc6798195d3b90005a1501a12f7
#   Building wheel for backtesting (setup.py) ... done
#   Created wheel for backtesting: filename=Backtesting-0.3.3-py3-none-any.whl size=173912 sha256=dc0c25ddc13ad8bdb49dc5b17c3751341ee6440535aa79d5db2ddbb5fcf96559
#   Stored in directory: /root/.cache/pip/wheels/2c/56/19/bf7ee5e164aa99a976e3f64841c83b5ae0391c59d9aec011d0
# Successfully built tvdatafeed backtesting
# Installing collected packages: tvdatafeed, backtesting
# Successfully installed backtesting-0.3.3 tvdatafeed-2.1.0
# Collecting tradingview-screener==2.5.0
#   Downloading tradingview_screener-2.5.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pandas<3.0.0,>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from tradingview-screener==2.5.0) (2.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from tradingview-screener==2.5.0) (2.32.3)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.2->tradingview-screener==2.5.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.2->tradingview-screener==2.5.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.2->tradingview-screener==2.5.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.2->tradingview-screener==2.5.0) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->tradingview-screener==2.5.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->tradingview-screener==2.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->tradingview-screener==2.5.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->tradingview-screener==2.5.0) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.2->tradingview-screener==2.5.0) (1.17.0)
# Downloading tradingview_screener-2.5.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: tradingview-screener
# Successfully installed tradingview-screener-2.5.0
# Lütfen zaman dilimini seçin:
# 1. 15 Dakika
# 2. 30 Dakika
# 3. 45 Dakika
# 4. 1 Saat
# 5. 2 Saat
# 6. 4 Saat
# 7. Günlük
# 8. Haftalık
# 9. Aylık
# Seçiminiz (örnek: 6): 7
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# Seçilen Zaman Dilimi: Günlük
# ['A1CAP', 24.84, 20.0, 'False', 'False']
# ['ACSEL', 118.0, 28.57, 'False', 'False']
# ['ADEL', 33.68, 28.57, 'False', 'False']
# ['ADESE', 2.26, 37.5, 'False', 'False']
# ['ADGYO', 31.02, 20.0, 'False', 'False']
# ['AEFES', 165.7, 80.0, 'False', 'False']
# ['AFYON', 15.18, 55.56, 'False', 'False']
# ['AGESA', 141.9, 60.0, 'False', 'False']
# ['AGHOL', 309.0, 80.0, 'False', 'False']
# ['AGROT', 10.34, 50.0, 'False', 'False']
# ['AGYO', 7.19, 25.0, 'False', 'False']
# ['AHGAZ', 19.93, 50.0, 'False', 'False']
# ['AHSGY', 23.56, 0.0, 'False', 'False']
# ['AKBNK', 66.0, 33.33, 'False', 'False']
# ['AKCNS', 184.6, 42.86, 'False', 'False']
# ['AKENR', 14.38, 28.57, 'False', 'False']
# ['AKFGY', 2.12, 42.86, 'False', 'False']
# ['AKFYE', 19.77, 50.0, 'False', 'False']
# ['AKGRT', 7.99, 50.0, 'False', 'False']
# ['AKMGY', 219.3, 60.0, 'False', 'False']
# ['AKSA', 11.07, 33.33, 'False', 'False']
# ['AKSEN', 40.68, 57.14, 'False', 'False']
# ['AKSGY', 7.42, 71.43, 'False', 'False']
# ['AKSUE', 11.99, 22.22, 'False', 'False']
# ['AKYHO', 2.68, 40.0, 'False', 'False']
# ['ALARK', 91.3, 40.0, 'False', 'False']
# ['ALBRK', 7.28, 57.14, 'False', 'False']
# ['ALCAR', 998.5, 50.0, 'False', 'False']
# ['ALCTL', 117.5, 28.57, 'False', 'False']
# ['ALFAS', 77.0, 60.0, 'False', 'False']
# ['ALGYO', 21.3, 37.5, 'False', 'False']
# ['ALKA', 9.67, 33.33, 'False', 'False']
# ['ALKIM', 19.42, 50.0, 'False', 'False']
# ['ALKLC', 26.66, 0.0, 'False', 'False']
# ['ALMAD', 7.7, 60.0, 'False', 'False']
# ['ALTIN', 31.2, 80.0, 'False', 'False']
# ['ALTNY', 79.1, 0.0, 'False', 'False']
# ['ALVES', 37.0, 33.33, 'False', 'True']
# ['ANELE', 14.95, 60.0, 'False', 'False']
# ['ANGEN', 14.37, 16.67, 'False', 'False']
# ['ANHYT', 104.2, 80.0, 'False', 'False']
# ['ANSGR', 113.9, 100.0, 'False', 'False']
# ['APBDL', 22.65, 33.33, 'False', 'False']
# ['APX30', 26.63, 50.0, 'False', 'False']
# ['ARASE', 52.1, 33.33, 'False', 'False']
# ['ARCLK', 128.0, 50.0, 'False', 'False']
# ['ARDYZ', 38.08, 50.0, 'False', 'False']
# ['ARENA', 36.12, 62.5, 'False', 'False']
# ['ARMGD', 35.8, nan, 'False', 'False']
# ['ARSAN', 20.88, 57.14, 'False', 'False']
# ['ARTMS', 30.54, 50.0, 'False', 'False']
# ['ARZUM', 37.52, 50.0, 'False', 'False']
# ['ASELS', 81.05, 42.86, 'False', 'False']
# ['ASGYO', 11.85, 50.0, 'False', 'False']
# ['ASTOR', 123.0, 50.0, 'False', 'False']
# ['ASUZU', 64.8, 40.0, 'False', 'False']
# ['ATAGY', 11.34, 33.33, 'False', 'False']
# ['ATAKP', 46.14, 20.0, 'False', 'False']
# ['ATATP', 116.0, 60.0, 'False', 'False']
# ['ATEKS', 163.2, 42.86, 'False', 'False']
# ['ATLAS', 6.08, 71.43, 'False', 'False']
# ['ATSYH', 43.62, 14.29, 'False', 'False']
# ['AVGYO', 8.15, 22.22, 'False', 'False']
# ['AVHOL', 35.52, 60.0, 'False', 'False']
# ['AVOD', 3.51, 33.33, 'False', 'False']
# ['AVPGY', 57.8, 33.33, 'False', 'False']
# ['AYCES', 500.5, 57.14, 'False', 'False']
# ['AYDEM', 23.2, 50.0, 'False', 'False']
# ['AYEN', 30.38, 57.14, 'False', 'False']
# ['AYES', 8.0, 41.67, 'False', 'False']
# ['AYGAZ', 160.8, 80.0, 'False', 'False']
# ['AZTEK', 49.0, 40.0, 'False', 'False']
# ['BAGFS', 23.14, 37.5, 'False', 'False']
# ['BAHKM', 49.3, 100.0, 'False', 'False']
# ['BAKAB', 34.62, 33.33, 'False', 'False']
# ['BALAT', 60.9, 41.67, 'False', 'False']
# ['BANVT', 288.25, 75.0, 'False', 'False']
# ['BARMA', 17.28, 33.33, 'False', 'False']
# ['BASCM', 11.2, 33.33, 'False', 'False']
# ['BASGZ', 30.28, 80.0, 'False', 'False']
# ['BAYRK', 17.76, 40.0, 'False', 'False']
# ['BEGYO', 7.0, 40.0, 'False', 'False']
# ['BERA', 16.46, 50.0, 'False', 'False']
# ['BEYAZ', 28.0, 66.67, 'False', 'False']
# ['BFREN', 666.0, 42.86, 'False', 'False']
# ['BIENY', 34.86, 80.0, 'False', 'False']
# ['BIGCH', 30.64, 80.0, 'False', 'False']
# ['BIMAS', 509.0, 50.0, 'False', 'False']
# ['BINBN', 92.1, 0.0, 'False', 'False']
# ['BINHO', 295.0, 25.0, 'False', 'False']
# ['BIOEN', 15.8, 33.33, 'False', 'False']
# ['BIZIM', 28.88, 50.0, 'False', 'False']
# ['BJKAS', 4.83, 28.57, 'False', 'False']
# ['BLCYT', 16.73, 50.0, 'False', 'False']
# ['BMSCH', 35.0, 80.0, 'False', 'False']
# ['BMSTL', 28.9, 66.67, 'False', 'False']
# ['BNTAS', 11.99, 50.0, 'False', 'False']
# ['BOBET', 23.62, 50.0, 'False', 'False']
# ['BORLS', 71.5, 50.0, 'False', 'False']
# ['BORSK', 22.86, 33.33, 'False', 'False']
# ['BOSSA', 6.9, 60.0, 'False', 'False']
# ['BRISA', 86.55, 40.0, 'False', 'False']
# ['BRKO', 13.4, 27.27, 'False', 'False']
# ['BRKSN', 23.96, 33.33, 'False', 'False']
# ['BRKVY', 61.95, 40.0, 'False', 'False']
# ['BRLSM', 15.13, 66.67, 'False', 'False']
# ['BRMEN', 5.1, 62.5, 'False', 'False']
# ['BRSAN', 410.25, 20.0, 'False', 'False']
# ['BRYAT', 1910.0, 33.33, 'False', 'False']
# ['BSOKE', 10.14, 42.86, 'False', 'False']
# ['BTCIM', 4.08, 66.67, 'False', 'False']
# ['BUCIM', 9.08, 66.67, 'False', 'False']
# ['BURCE', 17.86, 50.0, 'False', 'True']
# ['BURVA', 107.0, 66.67, 'False', 'False']
# ['BVSAN', 94.2, 80.0, 'False', 'False']
# ['BYDNR', 25.12, 40.0, 'False', 'False']
# ['CANTE', 1.65, 16.67, 'False', 'False']
# ['CASA', 80.2, 27.27, 'False', 'False']
# ['CATES', 38.0, 33.33, 'False', 'False']
# ['CCOLA', 61.2, 83.33, 'False', 'False']
# ['CELHA', 23.26, 66.67, 'False', 'False']
# ['CEMAS', 3.28, 10.0, 'False', 'True']
# ['CEMTS', 9.26, 33.33, 'False', 'False']
# ['CEMZY', 12.84, 100.0, 'False', 'False']
# ['CEOEM', 26.12, 33.33, 'False', 'False']
# ['CGCAM', 34.22, 0.0, 'False', 'False']
# ['CIMSA', 50.9, 33.33, 'False', 'False']
# ['CLEBI', 1915.0, 33.33, 'False', 'False']
# ['CMBTN', 2535.0, 42.86, 'False', 'False']
# ['CMENT', 425.0, 50.0, 'False', 'False']
# ['CONSE', 2.7, 75.0, 'False', 'False']
# ['COSMO', 115.0, 50.0, 'False', 'False']
# ['CRDFA', 6.05, 57.14, 'False', 'False']
# ['CRFSA', 103.5, 28.57, 'False', 'False']
# ['CUSAN', 24.3, 80.0, 'False', 'True']
# ['CVKMD', 341.25, 83.33, 'False', 'False']
# ['CWENE', 21.24, 50.0, 'False', 'False']
# ['DAGHL', 16.0, 12.5, 'False', 'False']
# ['DAGI', 19.75, 42.86, 'False', 'False']
# ['DAPGM', 7.44, 60.0, 'False', 'False']
# ['DARDL', 5.2, 25.0, 'False', 'False']
# ['DCTTR', 34.08, 50.0, 'False', 'False']
# ['DENGE', 3.57, 80.0, 'False', 'False']
# ['DERHL', 19.61, 62.5, 'False', 'False']
# ['DERIM', 38.66, 50.0, 'False', 'False']
# ['DESA', 10.14, 33.33, 'False', 'False']
# ['DESPC', 46.02, 28.57, 'False', 'False']
# ['DEVA', 76.3, 75.0, 'False', 'False']
# ['DGATE', 45.8, 50.0, 'False', 'False']
# ['DGGYO', 42.18, 50.0, 'False', 'False']
# ['DGNMO', 8.9, 50.0, 'False', 'False']
# ['DIRIT', 25.0, 33.33, 'False', 'False']
# ['DITAS', 15.35, 60.0, 'False', 'False']
# ['DMRGD', 12.43, 40.0, 'False', 'False']
# ['DMSAS', 9.25, 57.14, 'False', 'False']
# ['DNISI', 27.34, 42.86, 'False', 'False']
# ['DOAS', 194.2, 50.0, 'False', 'False']
# ['DOBUR', 185.0, 50.0, 'False', 'False']
# ['DOCO', 6400.0, 66.67, 'False', 'False']
# ['DOFER', 28.98, 25.0, 'False', 'False']
# ['DOGUB', 19.85, 50.0, 'False', 'False']
# ['DOHOL', 14.3, 80.0, 'False', 'False']
# ['DOKTA', 24.84, 40.0, 'False', 'False']
# ['DURDO', 19.41, 33.33, 'False', 'False']
# ['DURKN', 16.25, 100.0, 'False', 'False']
# ['DYOBY', 29.18, 62.5, 'False', 'False']
# ['DZGYO', 9.92, 33.33, 'False', 'False']
# ['EBEBK', 54.5, 33.33, 'False', 'False']
# ['ECILC', 46.28, 37.5, 'False', 'False']
# ['ECZYT', 193.7, 28.57, 'False', 'False']
# ['EDATA', 13.28, 66.67, 'False', 'False']
# ['EDIP', 20.84, 42.86, 'False', 'False']
# ['EFORC', 61.8, 100.0, 'False', 'False']
# ['EGEEN', 9832.5, 40.0, 'False', 'False']
# ['EGEGY', 15.0, nan, 'False', 'False']
# ['EGEPO', 26.0, 22.22, 'False', 'False']
# ['EGGUB', 74.75, 80.0, 'False', 'False']
# ['EGPRO', 22.86, 60.0, 'False', 'False']
# ['EGSER', 3.81, 28.57, 'False', 'False']
# ['EKGYO', 14.65, 44.44, 'False', 'False']
# ['EKIZ', 55.0, 27.27, 'False', 'False']
# ['EKOS', 24.98, 33.33, 'False', 'False']
# ['EKSUN', 6.3, 40.0, 'False', 'False']
# ['ELITE', 37.0, 28.57, 'False', 'False']
# ['EMKEL', 16.0, 57.14, 'False', 'False']
# ['EMNIS', 243.4, 33.33, 'False', 'False']
# ['ENERY', 240.2, 75.0, 'False', 'False']
# ['ENJSA', 61.3, 60.0, 'False', 'False']
# ['ENKAI', 50.45, 50.0, 'False', 'False']
# ['ENSRI', 18.47, 42.86, 'False', 'False']
# ['ENTRA', 8.53, 100.0, 'False', 'False']
# ['EPLAS', 6.72, 40.0, 'False', 'False']
# ['ERBOS', 185.1, 50.0, 'False', 'False']
# ['ERCB', 95.2, 66.67, 'False', 'False']
# ['EREGL', 23.06, 42.86, 'False', 'False']
# ['ERSU', 17.15, 40.0, 'False', 'False']
# ['ESCAR', 44.44, 66.67, 'False', 'False']
# ['ESCOM', 54.15, 28.57, 'False', 'False']
# ['ESEN', 27.54, 50.0, 'False', 'False']
# ['ETILR', 6.1, 30.0, 'False', 'False']
# ['ETYAT', 11.3, 40.0, 'False', 'False']
# ['EUHOL', 8.85, 50.0, 'False', 'False']
# ['EUKYO', 13.68, 42.86, 'False', 'False']
# ['EUPWR', 33.4, 66.67, 'False', 'False']
# ['EUREN', 4.5, 50.0, 'False', 'True']
# ['EUYO', 13.1, 25.0, 'False', 'False']
# ['EYGYO', 7.59, 25.0, 'False', 'False']
# ['FADE', 16.17, 60.0, 'False', 'False']
# ['FENER', 46.86, 42.86, 'False', 'False']
# ['FLAP', 9.49, 44.44, 'False', 'False']
# ['FMIZP', 319.75, 16.67, 'False', 'False']
# ['FONET', 16.6, 37.5, 'False', 'False']
# ['FORMT', 7.15, 60.0, 'False', 'False']
# ['FORTE', 54.0, 60.0, 'False', 'False']
# ['FRIGO', 8.19, 33.33, 'False', 'False']
# ['FROTO', 922.0, 66.67, 'False', 'False']
# ['FZLGY', 27.04, 20.0, 'False', 'False']
# ['GARAN', 132.8, 71.43, 'False', 'False']
# ['GARFA', 20.16, 42.86, 'False', 'False']
# ['GEDIK', 7.84, 33.33, 'False', 'False']
# ['GEDZA', 32.12, 60.0, 'False', 'False']
# ['GENIL', 104.7, 80.0, 'False', 'False']
# ['GENTS', 11.14, 66.67, 'False', 'False']
# ['GEREL', 9.96, 50.0, 'False', 'False']
# ['GESAN', 46.16, 37.5, 'False', 'False']
# ['GIPTA', 45.1, 33.33, 'False', 'False']
# ['GLBMD', 10.89, 40.0, 'False', 'False']
# ['GLCVY', 51.3, 66.67, 'False', 'False']
# ['GLDTR', 263.0, 75.0, 'False', 'False']
# ['GLRYH', 12.01, 25.0, 'False', 'False']
# ['GLYHO', 18.42, 50.0, 'False', 'False']
# ['GMSTR', 216.0, 60.0, 'False', 'False']
# ['GMTAS', 12.3, 22.22, 'False', 'False']
# ['GOKNR', 22.9, 60.0, 'False', 'False']
# ['GOLTS', 427.0, 66.67, 'False', 'False']
# ['GOODY', 18.23, 60.0, 'False', 'True']
# ['GOZDE', 24.86, 33.33, 'False', 'False']
# ['GRNYO', 9.3, 40.0, 'False', 'False']
# ['GRSEL', 201.7, 83.33, 'False', 'False']
# ['GRTHO', 168.8, 100.0, 'False', 'False']
# ['GSDDE', 8.9, 42.86, 'False', 'False']
# ['GSDHO', 3.82, 50.0, 'False', 'False']
# ['GSRAY', 2.13, 25.0, 'False', 'False']
# ['GUBRF', 283.75, 50.0, 'False', 'False']
# ['GUNDG', 62.25, 100.0, 'False', 'False']
# ['GWIND', 30.6, 80.0, 'False', 'False']
# ['GZNMI', 73.75, 100.0, 'False', 'False']
# ['HALKB', 18.0, 37.5, 'False', 'False']
# ['HATEK', 14.69, 50.0, 'False', 'False']
# ['HATSN', 44.7, 50.0, 'False', 'False']
# ['HDFGS', 1.79, 50.0, 'False', 'False']
# ['HEDEF', 4.43, 60.0, 'False', 'False']
# ['HEKTS', 3.83, 25.0, 'False', 'False']
# ['HKTM', 18.01, 37.5, 'False', 'False']
# ['HLGYO', 2.65, 57.14, 'False', 'False']
# ['HOROZ', 63.1, 66.67, 'False', 'False']
# ['HRKET', 71.45, 0.0, 'False', 'False']
# ['HTTBT', 42.38, 66.67, 'False', 'False']
# ['HUBVC', 2.36, 50.0, 'False', 'False']
# ['HUNER', 3.9, 60.0, 'False', 'False']
# ['HURGZ', 5.16, 25.0, 'False', 'False']
# ['ICBCT', 14.64, 28.57, 'False', 'False']
# ['ICUGS', 26.76, 60.0, 'False', 'False']
# ['IDGYO', 2.83, 28.57, 'False', 'False']
# ['IEYHO', 11.16, 50.0, 'False', 'False']
# ['IHAAS', 16.52, 25.0, 'False', 'False']
# ['IHEVA', 2.65, 66.67, 'False', 'False']
# ['IHGZT', 1.51, 60.0, 'False', 'False']
# ['IHLAS', 3.39, 42.86, 'False', 'False']
# ['IHLGM', 2.1, 42.86, 'False', 'False']
# ['IHYAY', 3.4, 33.33, 'False', 'False']
# ['IMASM', 2.95, 33.33, 'False', 'False']
# ['INDES', 7.88, 42.86, 'False', 'False']
# ['INFO', 2.62, 57.14, 'False', 'False']
# ['INGRM', 439.25, 42.86, 'False', 'False']
# ['INTEK', 455.5, 37.5, 'False', 'False']
# ['INTEM', 224.2, 40.0, 'False', 'False']
# ['INVEO', 7.41, 25.0, 'False', 'False']
# ['INVES', 282.75, 60.0, 'False', 'False']
# ['IPEKE', 58.0, 37.5, 'False', 'False']
# ['ISBIR', 106.0, 70.0, 'False', 'False']
# ['ISBTR', 529502.5, 25.0, 'True', 'False']
# ['ISCTR', 14.28, 71.43, 'False', 'False']
# ['ISDMR', 39.38, 42.86, 'False', 'False']
# ['ISFIN', 13.24, 42.86, 'False', 'False']
# ['ISGYO', 19.49, 22.22, 'False', 'False']
# ['ISKPL', 18.83, 40.0, 'False', 'False']
# ['ISKUR', 5400000.0, 54.55, 'False', 'False']
# ['ISMEN', 45.9, 66.67, 'False', 'False']
# ['ISSEN', 9.14, 0.0, 'False', 'False']
# ['IZENR', 4.6, 100.0, 'False', 'False']
# ['IZFAS', 78.05, 100.0, 'False', 'False']
# ['IZINV', 41.78, 60.0, 'False', 'False']
# ['IZMDC', 5.38, 33.33, 'False', 'True']
# ['JANTS', 25.96, 50.0, 'False', 'False']
# ['KAPLM', 174.6, 60.0, 'False', 'False']
# ['KAREL', 10.35, 50.0, 'False', 'False']
# ['KARSN', 12.07, 50.0, 'False', 'False']
# ['KARTN', 112.3, 75.0, 'False', 'False']
# ['KARYE', 27.96, 33.33, 'False', 'False']
# ['KATMR', 2.11, 66.67, 'False', 'False']
# ['KAYSE', 19.6, 16.67, 'False', 'False']
# ['KBORU', 78.4, 33.33, 'False', 'False']
# ['KCAER', 13.41, 42.86, 'False', 'False']
# ['KCHOL', 178.1, 75.0, 'False', 'False']
# ['KENT', 953.0, 40.0, 'False', 'False']
# ['KERVN', 2.34, 75.0, 'False', 'False']
# ['KERVT', 13.07, 42.86, 'False', 'False']
# ['KFEIN', 101.4, 42.86, 'False', 'False']
# ['KGYO', 43.0, 12.5, 'False', 'False']
# ['KIMMR', 11.05, 42.86, 'False', 'False']
# ['KLGYO', 5.27, 60.0, 'False', 'False']
# ['KLKIM', 33.9, 71.43, 'False', 'False']
# ['KLMSN', 29.42, 50.0, 'False', 'False']
# ['KLNMA', 13.79, 33.33, 'False', 'False']
# ['KLRHO', 31.16, 50.0, 'False', 'False']
# ['KLSER', 35.82, 0.0, 'False', 'False']
# ['KLSYN', 5.63, 42.86, 'False', 'False']
# ['KMPUR', 18.35, 40.0, 'False', 'False']
# ['KNFRT', 13.12, 50.0, 'False', 'False']
# ['KOCMT', 15.49, 0.0, 'False', 'False']
# ['KONKA', 39.84, 25.0, 'False', 'False']
# ['KONTR', 37.12, 33.33, 'False', 'False']
# ['KONYA', 6420.0, 50.0, 'False', 'False']
# ['KOPOL', 6.03, 75.0, 'False', 'False']
# ['KORDS', 71.55, 28.57, 'False', 'False']
# ['KOTON', 20.1, 50.0, 'False', 'False']
# ['KOZAA', 71.75, 42.86, 'False', 'False']
# ['KOZAL', 23.24, 37.5, 'False', 'False']
# ['KRDMA', 28.6, 80.0, 'False', 'False']
# ['KRDMB', 24.2, 80.0, 'False', 'False']
# ['KRDMD', 26.22, 83.33, 'False', 'False']
# ['KRGYO', 9.69, 60.0, 'True', 'False']
# ['KRONT', 22.9, 50.0, 'False', 'False']
# ['KRPLS', 7.31, 50.0, 'False', 'False']
# ['KRSTL', 5.93, 14.29, 'False', 'False']
# ['KRTEK', 35.88, 42.86, 'False', 'False']
# ['KRVGD', 2.22, 50.0, 'False', 'False']
# ['KSTUR', 2802.5, 50.0, 'False', 'False']
# ['KTLEV', 57.4, 100.0, 'False', 'False']
# ['KTSKR', 62.65, 14.29, 'False', 'False']
# ['KUTPO', 77.5, 75.0, 'False', 'False']
# ['KUVVA', 58.6, 25.0, 'False', 'False']
# ['KUYAS', 20.62, 71.43, 'False', 'False']
# ['KZBGY', 5.49, 25.0, 'False', 'False']
# ['KZGYO', 21.02, 28.57, 'False', 'False']
# ['LIDER', 140.0, 57.14, 'False', 'False']
# ['LIDFA', 2.97, 42.86, 'False', 'False']
# ['LILAK', 29.3, 33.33, 'False', 'False']
# ['LINK', 496.25, 50.0, 'False', 'False']
# ['LKMNH', 21.46, 60.0, 'False', 'False']
# ['LMKDC', 33.64, 100.0, 'False', 'False']
# ['LOGO', 113.6, 57.14, 'False', 'False']
# ['LRSHO', 2.18, 28.57, 'False', 'False']
# ['LUKSK', 92.7, 40.0, 'False', 'False']
# ['LYDHO', 112.9, 80.0, 'False', 'False']
# ['LYDYE', 11585.0, 83.33, 'False', 'False']
# ['MAALT', 799.0, 33.33, 'False', 'False']
# ['MACKO', 104.9, 33.33, 'False', 'False']
# ['MAGEN', 23.1, 60.0, 'False', 'False']
# ['MAKIM', 22.26, 50.0, 'False', 'False']
# ['MAKTK', 6.81, 50.0, 'False', 'False']
# ['MANAS', 8.88, 50.0, 'False', 'False']
# ['MARBL', 13.11, 33.33, 'False', 'False']
# ['MARKA', 49.0, 33.33, 'False', 'False']
# ['MARTI', 3.34, 28.57, 'False', 'False']
# ['MAVI', 74.0, 50.0, 'False', 'False']
# ['MEDTR', 46.6, 33.33, 'False', 'False']
# ['MEGAP', 3.1, 66.67, 'True', 'False']
# ['MEGMT', 29.98, 33.33, 'False', 'False']
# ['MEKAG', 43.44, 20.0, 'False', 'False']
# ['MEPET', 9.19, 33.33, 'False', 'False']
# ['MERCN', 16.0, 50.0, 'False', 'False']
# ['MERIT', 14.21, 60.0, 'False', 'False']
# ['MERKO', 15.78, 57.14, 'False', 'False']
# ['METRO', 2.55, 57.14, 'False', 'False']
# ['METUR', 16.96, 37.5, 'False', 'False']
# ['MGROS', 549.5, 80.0, 'False', 'False']
# ['MHRGY', 4.84, 50.0, 'False', 'False']
# ['MIATK', 39.28, 50.0, 'False', 'False']
# ['MMCAS', 22.9, 41.67, 'False', 'False']
# ['MNDRS', 10.71, 42.86, 'False', 'False']
# ['MNDTR', 6.38, 33.33, 'False', 'False']
# ['MOBTL', 4.21, 33.33, 'False', 'False']
# ['MOGAN', 10.59, 50.0, 'False', 'False']
# ['MPARK', 395.0, 75.0, 'False', 'False']
# ['MRGYO', 1.72, 57.14, 'False', 'False']
# ['MRSHL', 1513.0, 25.0, 'False', 'False']
# ['MSGYO', 15.04, 42.86, 'False', 'False']
# ['MTRKS', 22.0, 50.0, 'False', 'False']
# ['MTRYO', 7.29, 42.86, 'False', 'False']
# ['MZHLD', 6.45, 33.33, 'False', 'False']
# ['NATEN', 77.35, 50.0, 'False', 'False']
# ['NETAS', 67.1, 28.57, 'False', 'False']
# ['NIBAS', 17.53, 33.33, 'False', 'False']
# ['NTGAZ', 6.28, 37.5, 'False', 'False']
# ['NTHOL', 43.5, 62.5, 'False', 'False']
# ['NUGYO', 8.08, 60.0, 'False', 'False']
# ['NUHCM', 286.25, 60.0, 'False', 'False']
# ['OBAMS', 51.3, 50.0, 'False', 'True']
# ['OBASE', 31.8, 50.0, 'False', 'False']
# ['ODAS', 5.92, 25.0, 'False', 'False']
# ['ODINE', 111.9, 33.33, 'False', 'False']
# ['OFSYM', 41.22, 50.0, 'False', 'False']
# ['ONCSM', 115.4, 50.0, 'False', 'False']
# ['ONRYT', 72.5, 50.0, 'False', 'False']
# ['ORCAY', 9.03, 28.57, 'False', 'False']
# ['ORGE', 87.05, 37.5, 'False', 'False']
# ['ORMA', 195.8, 46.15, 'False', 'False']
# ['OSMEN', 9.85, 100.0, 'False', 'False']
# ['OSTIM', 10.53, 42.86, 'False', 'False']
# ['OTKAR', 430.0, 50.0, 'False', 'False']
# ['OTTO', 326.0, 44.44, 'False', 'False']
# ['OYAKC', 25.42, 83.33, 'False', 'False']
# ['OYAYO', 25.2, 50.0, 'False', 'False']
# ['OYLUM', 8.27, 33.33, 'False', 'False']
# ['OYYAT', 35.66, 40.0, 'False', 'False']
# ['OZATD', 90.0, 100.0, 'False', 'False']
# ['OZGYO', 5.59, 50.0, 'False', 'False']
# ['OZKGY', 12.87, 66.67, 'False', 'False']
# ['OZRDN', 8.99, 100.0, 'False', 'False']
# ['OZSUB', 33.12, 57.14, 'False', 'False']
# ['OZYSR', 27.24, 0.0, 'False', 'False']
# ['PAGYO', 63.65, 50.0, 'False', 'False']
# ['PAMEL', 95.15, 20.0, 'False', 'False']
# ['PAPIL', 13.09, 28.57, 'False', 'False']
# ['PARSN', 90.2, 25.0, 'False', 'False']
# ['PASEU', 32.3, 75.0, 'False', 'False']
# ['PATEK', 111.0, 50.0, 'False', 'False']
# ['PCILT', 16.82, 62.5, 'False', 'False']
# ['PEHOL', 5.22, 66.67, 'False', 'False']
# ['PEKGY', 1.5, 40.0, 'False', 'False']
# ['PENGD', 6.68, 75.0, 'False', 'False']
# ['PENTA', 15.78, 75.0, 'False', 'False']
# ['PETKM', 17.99, 14.29, 'False', 'False']
# ['PETUN', 10.0, 40.0, 'False', 'False']
# ['PGSUS', 223.0, 50.0, 'False', 'False']
# ['PINSU', 6.4, 66.67, 'False', 'False']
# ['PKART', 72.5, 60.0, 'False', 'False']
# ['PKENT', 249.1, 60.0, 'False', 'False']
# ['PLTUR', 31.88, 44.44, 'False', 'False']
# ['PNLSN', 50.4, 60.0, 'False', 'False']
# ['PNSUT', 10.04, 33.33, 'False', 'False']
# ['POLHO', 11.36, 28.57, 'False', 'True']
# ['POLTK', 6827.5, 50.0, 'False', 'False']
# ['PRDGS', 5.41, 33.33, 'False', 'False']
# ['PRKAB', 29.94, 33.33, 'False', 'False']
# ['PRKME', 21.88, 50.0, 'False', 'False']
# ['PRZMA', 7.1, 50.0, 'False', 'False']
# ['PSDTC', 80.15, 50.0, 'False', 'False']
# ['PSGYO', 1.58, 42.86, 'False', 'False']
# ['QNBFK', 43.38, 22.22, 'False', 'False']
# ['QNBTR', 275.5, 42.86, 'False', 'False']
# ['QTEMZ', 294.1, 50.0, 'False', 'False']
# ['QUAGR', 3.57, 50.0, 'False', 'False']
# ['RALYH', 307.25, 50.0, 'False', 'False']
# ['RAYSG', 650.0, 50.0, 'False', 'False']
# ['REEDR', 13.27, 50.0, 'False', 'False']
# ['RGYAS', 121.8, 33.33, 'False', 'False']
# ['RNPOL', 27.9, 50.0, 'False', 'False']
# ['RODRG', 18.98, 25.0, 'False', 'False']
# ['RTALB', 18.88, 28.57, 'False', 'False']
# ['RUBNS', 26.6, 37.5, 'False', 'False']
# ['RYGYO', 16.95, 42.86, 'False', 'False']
# ['RYSAS', 21.44, 75.0, 'False', 'False']
# ['SAFKR', 56.1, 50.0, 'False', 'False']
# ['SAHOL', 99.6, 50.0, 'False', 'False']
# ['SAMAT', 21.78, 30.0, 'False', 'False']
# ['SANEL', 22.78, 16.67, 'False', 'False']
# ['SANFM', 46.2, 100.0, 'False', 'False']
# ['SANKO', 24.3, 62.5, 'False', 'False']
# ['SARKY', 19.58, 28.57, 'False', 'False']
# ['SASA', 3.91, 12.5, 'False', 'False']
# ['SAYAS', 44.3, 25.0, 'False', 'False']
# ['SDTTR', 211.5, 75.0, 'False', 'False']
# ['SEGMN', 21.8, 100.0, 'False', 'False']
# ['SEGYO', 4.77, 33.33, 'False', 'False']
# ['SEKFK', 7.29, 42.86, 'False', 'False']
# ['SEKUR', 12.3, 60.0, 'False', 'False']
# ['SELEC', 77.5, 28.57, 'False', 'False']
# ['SELGD', 48.82, 50.0, 'False', 'False']
# ['SELVA', 11.34, 37.5, 'False', 'False']
# ['SEYKM', 3.25, 50.0, 'False', 'False']
# ['SILVR', 20.18, 25.0, 'False', 'False']
# ['SISE', 39.72, 14.29, 'False', 'False']
# ['SKBNK', 4.57, 28.57, 'False', 'False']
# ['SKTAS', 4.9, 28.57, 'False', 'False']
# ['SKYLP', 130.5, 50.0, 'False', 'False']
# ['SKYMD', 12.45, 50.0, 'False', 'False']
# ['SMART', 28.28, 60.0, 'False', 'False']
# ['SMRTG', 41.48, 33.33, 'False', 'False']
# ['SMRVA', 26.5, 0.0, 'False', 'False']
# ['SNGYO', 3.18, 57.14, 'False', 'False']
# ['SNICA', 5.19, 28.57, 'False', 'False']
# ['SNKRN', 56.9, 41.67, 'False', 'False']
# ['SNPAM', 60.45, 28.57, 'False', 'False']
# ['SODSN', 105.4, 33.33, 'False', 'False']
# ['SOKE', 12.18, 33.33, 'False', 'False']
# ['SOKM', 39.1, 50.0, 'False', 'False']
# ['SONME', 88.9, 80.0, 'False', 'False']
# ['SRVGY', 253.5, 20.0, 'False', 'False']
# ['SUMAS', 364.75, 66.67, 'False', 'False']
# ['SUNTK', 41.7, 37.5, 'False', 'False']
# ['SURGY', 42.98, 75.0, 'False', 'False']
# ['SUWEN', 25.5, 42.86, 'False', 'False']
# ['TABGD', 169.7, 100.0, 'False', 'False']
# ['TARKM', 425.75, 50.0, 'False', 'False']
# ['TATEN', 50.0, 100.0, 'False', 'False']
# ['TATGD', 13.68, 20.0, 'False', 'False']
# ['TAVHL', 285.0, 42.86, 'False', 'False']
# ['TBORG', 135.2, 60.0, 'False', 'False']
# ['TCELL', 100.3, 66.67, 'False', 'False']
# ['TCKRC', 31.6, 100.0, 'False', 'False']
# ['TDGYO', 12.87, 50.0, 'False', 'False']
# ['TEKTU', 4.54, 50.0, 'False', 'False']
# ['TERA', 37.62, 50.0, 'False', 'False']
# ['TEZOL', 17.53, 42.86, 'False', 'False']
# ['TGSAS', 59.5, 33.33, 'False', 'False']
# ['THYAO', 303.5, 57.14, 'False', 'False']
# ['TKFEN', 65.05, 44.44, 'False', 'False']
# ['TKNSA', 28.8, 37.5, 'False', 'False']
# ['TLMAN', 96.3, 60.0, 'False', 'False']
# ['TMPOL', 78.85, 75.0, 'False', 'False']
# ['TMSN', 118.6, 28.57, 'False', 'False']
# ['TNZTP', 56.0, 50.0, 'False', 'False']
# ['TOASO', 206.2, 60.0, 'False', 'False']
# ['TRCAS', 27.2, 50.0, 'False', 'False']
# ['TRGYO', 61.3, 60.0, 'False', 'False']
# ['TRILC', 17.27, 28.57, 'False', 'False']
# ['TSGYO', 7.12, 57.14, 'False', 'False']
# ['TSKB', 13.39, 57.14, 'False', 'False']
# ['TSPOR', 1.18, 50.0, 'False', 'False']
# ['TTKOM', 46.22, 60.0, 'False', 'False']
# ['TTRAK', 700.0, 50.0, 'False', 'False']
# ['TUCLK', 10.26, 20.0, 'False', 'False']
# ['TUKAS', 6.69, 28.57, 'False', 'False']
# ['TUPRS', 148.1, 28.57, 'False', 'False']
# ['TUREX', 174.2, 57.14, 'False', 'False']
# ['TURGG', 531.0, 50.0, 'False', 'False']
# ['TURSG', 17.34, 71.43, 'False', 'False']
# ['UFUK', 519.0, 57.14, 'False', 'False']
# ['ULAS', 30.98, 57.14, 'False', 'False']
# ['ULKER', 114.0, 37.5, 'False', 'False']
# ['ULUFA', 17.2, 42.86, 'False', 'False']
# ['ULUSE', 168.0, 42.86, 'False', 'False']
# ['ULUUN', 6.38, 33.33, 'False', 'False']
# ['UNLU', 14.52, 40.0, 'False', 'True']
# ['USAK', 14.12, 50.0, 'False', 'False']
# ['USDTR', 3327.0, 100.0, 'False', 'False']
# ['VAKBN', 25.5, 33.33, 'True', 'False']
# ['VAKFN', 2.07, 42.86, 'False', 'False']
# ['VAKKO', 81.2, 40.0, 'False', 'False']
# ['VANGD', 23.7, 71.43, 'False', 'False']
# ['VBTYZ', 25.16, 40.0, 'False', 'False']
# ['VERUS', 271.25, 66.67, 'False', 'False']
# ['VESBE', 15.78, 28.57, 'False', 'False']
# ['VESTL', 65.35, 75.0, 'False', 'False']
# ['VKFYO', 18.37, 40.0, 'False', 'False']
# ['VKGYO', 2.09, 50.0, 'False', 'False']
# ['VKING', 30.96, 40.0, 'False', 'False']
# ['VRGYO', 3.11, 100.0, 'False', 'False']
# ['YAPRK', 860.0, 66.67, 'False', 'False']
# ['YATAS', 26.76, 80.0, 'False', 'False']
# ['YAYLA', 20.3, 50.0, 'False', 'False']
# ['YBTAS', 127000.0, 44.44, 'False', 'False']
# ['YEOTK', 53.5, 33.33, 'False', 'False']
# ['YESIL', 1.99, 28.57, 'False', 'False']
# ['YGGYO', 65.05, 50.0, 'False', 'False']
# ['YGYO', 9.25, 57.14, 'False', 'False']
# ['YIGIT', 34.42, 50.0, 'False', 'False']
# ['YKBNK', 31.7, 50.0, 'False', 'False']
# ['YKSLN', 7.38, 50.0, 'False', 'False']
# ['YONGA', 57.9, 27.27, 'False', 'False']
# ['YUNSA', 6.53, 60.0, 'False', 'False']
# ERROR:tvDatafeed.main:Connection to remote host was lost.
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# ['YYLGD', 9.86, 66.67, 'False', 'False']
# ['Z30KE', 97.72, 42.86, 'False', 'False']
# ['Z30KP', 138.95, 83.33, 'False', 'False']
# ['ZEDUR', 8.6, 40.0, 'False', 'False']
# ['ZGOLD', 325.5, 100.0, 'False', 'False']
# ['ZOREN', 4.23, 28.57, 'False', 'False']
# ['ZPBDL', 151.4, 42.86, 'False', 'False']
# ['ZPLIB', 172.1, 50.0, 'False', 'False']
# ['ZRGYO', 13.74, 66.67, 'False', 'False']
#     Hisse Adı  Son Fiyat  Kazanma Oranı Giriş Sinyali Çıkış Sinyali
# 281     ISBTR  529502.50          25.00          True         False
# 332     KRGYO       9.69          60.00          True         False
# 368     MEGAP       3.10          66.67          True         False
# 549     VAKBN      25.50          33.33          True         False
