# %% [markdown]
# <a href="https://colab.research.google.com/github/talpt/pyton/blob/main/B%C4%B1st_100_D%C4%B0P_Hisse_Taramas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/rongardF/tvdatafeed tradingview-screener

import numpy as np
import pandas as pd
from tvDatafeed import TvDatafeed, Interval
from tradingview_screener import get_all_symbols
import warnings

warnings.simplefilter(action='ignore')

#Standart Moving Average
def sma(series, length):
    """
    Calculate the Simple Moving Average (SMA) for a given series.
    """
    return series.rolling(window=length).mean()

#Exponential Moving Average
def ema(series, length):
    """
    Calculate the Exponential Moving Average (EMA) for a given series.
    """
    return series.ewm(span=length, adjust=False).mean()


def Bankery(data):
    df=data.copy()
    close_minus_rolling_min = data['close'] - pd.Series(data['low']).rolling(window=27).min()
    percentage_change = close_minus_rolling_min / (pd.Series(data['high']).rolling(window=27).max() - pd.Series(data['low']).rolling(window=27).min()) * 100

    sma1 = sma(percentage_change, 5)
    sma2 = sma(sma1, 3)

    fundtrend = (3 * sma1 - 2 * sma2 - 50) * 1.032 + 50

    typ = (2 * data['close'] + data['high'] + data['low'] + data['open']) / 5
    lol = pd.Series(data['low']).rolling(window=34).min()
    hoh = pd.Series(data['high']).rolling(window=34).max()
    bullbearline = ema((typ - lol) / (hoh - lol) * 100, 13)
    bankerentry = (fundtrend > bullbearline) & (bullbearline < 25)
    df['Entry'] = (bankerentry==True)
    return df


tv = TvDatafeed()
Hisseler = get_all_symbols(market='turkey')
Hisseler = [symbol.replace('BIST:', '') for symbol in Hisseler]
Hisseler = sorted(Hisseler)


#Raporlama için kullanılacak başlıklar
Titles = ['Hisse Adı', 'Son Fiyat','Dip Sinyali']
df_signals = pd.DataFrame(columns=Titles)

for hisse in Hisseler:
    try:
        data = tv.get_hist(symbol=hisse, exchange='BIST', interval=Interval.in_1_hour, n_bars=100)
        data = data.reset_index()
        Banker = Bankery(data)
        Banker.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'}, inplace=True)
        Banker.set_index('datetime', inplace=True)
        Buy = False
        Signals = Banker.tail(2)
        Signals = Signals.reset_index()

        Entry = (Signals.loc[0, 'Entry'] == False) & (Signals.loc[1, 'Entry'] == True)
        Last_Price = Signals.loc[1, 'Close']
        L1 = [hisse, Last_Price,Entry]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except:
        pass

df_True = df_signals[(df_signals['Dip Sinyali'] == True)]
print(df_True)
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-ehpzo4bh
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-ehpzo4bh
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Collecting tradingview-screener
#   Downloading tradingview_screener-2.5.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (71.0.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.1.4)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.16.0)
# Downloading tradingview_screener-2.5.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.6 MB/s eta 0:00:00
# Building wheels for collected packages: tvdatafeed
#   Building wheel for tvdatafeed (setup.py) ... done
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17532 sha256=d6d38614d1d65b62e09653093780ee555c894c5be9fde41d1201a8a0d6fbe88a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s7vvxwev/wheels/e4/32/1e/21ebcacc6549d75fae3bf3ff75cee8fcbe4e5c189d88fbd5a1
# Successfully built tvdatafeed
# Installing collected packages: tvdatafeed, tradingview-screener
# Successfully installed tradingview-screener-2.5.0 tvdatafeed-2.1.0
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# ['A1CAP', 26.76, False]
# ['ACSEL', 137.5, False]
# ['ADEL', 544.0, False]
# ['ADESE', 2.18, False]
# ['ADGYO', 35.0, False]
# ['AEFES', 262.75, False]
# ['AFYON', 14.22, False]
# ['AGESA', 129.5, False]
# ['AGHOL', 417.5, False]
# ['AGROT', 19.27, False]
# ['AGYO', 7.71, False]
# ['AHGAZ', 13.23, False]
# ['AKBNK', 60.2, False]
# ['AKCNS', 146.9, False]
# ['AKENR', 12.36, False]
# ['AKFGY', 2.3, True]
# ['AKFYE', 23.9, False]
# ['AKGRT', 6.21, False]
# ['AKMGY', 247.4, False]
# ['AKSA', 10.16, True]
# ['AKSEN', 40.1, False]
# ['AKSGY', 19.9, True]
# ['AKSUE', 12.92, False]
# ['AKYHO', 10.3, False]
# ['ALARK', 106.1, False]
# ['ALBRK', 6.29, False]
# ['ALBTS', 2662.0, False]
# ['ALCAR', 1100.0, False]
# ['ALCTL', 98.5, False]
# ['ALDUK', 7400.0, False]
# ['ALFAS', 66.95, False]
# ['ALGYO', 52.15, False]
# ['ALKA', 28.12, False]
# ['ALKIM', 32.96, False]
# ['ALKLC', 25.06, False]
# ['ALMAD', 8.42, False]
# ['ALTIN', 25.93, False]
# ['ALTNY', 109.7, False]
# ['ALVES', 50.45, False]
# ['ANELE', 16.37, False]
# ['ANGEN', 12.51, False]
# ['ANHYT', 112.3, False]
# ['ANSGR', 97.25, False]
# ['APBDL', 23.4, False]
# ['APLIB', 39.2, False]
# ['APX30', 27.24, False]
# ['APYKF', 1750.0, False]
# ['APYKS', 1565.5, False]
# ['APYMD', 2590.0, True]
# ['APYVC', 5625.0, False]
# ['ARASE', 53.35, False]
# ['ARCLK', 160.7, True]
# ['ARDYZ', 39.1, False]
# ['ARENA', 39.64, True]
# ['ARSAN', 19.5, False]
# ['ARTMS', 58.25, False]
# ['ARZUM', 52.45, False]
# ['ASELS', 60.8, False]
# ['ASGYO', 12.8, False]
# ['ASTOR', 91.4, False]
# ['ASUZU', 82.15, False]
# ['ATAGY', 11.94, False]
# ['ATAKP', 49.9, False]
# ['ATATP', 114.9, False]
# ['ATEKS', 173.0, False]
# ['ATLAS', 5.8, False]
# ['ATSYH', 87.0, False]
# ['AVGYO', 8.03, False]
# ['AVHOL', 34.84, False]
# ['AVOD', 3.38, False]
# ['AVPGY', 45.06, False]
# ['AVTUR', 11.41, False]
# ['AYCES', 582.5, False]
# ['AYDEM', 29.94, False]
# ['AYEN', 31.66, False]
# ['AYES', 44.34, False]
# ['AYGAZ', 170.0, False]
# ['AZTEK', 66.1, False]
# ['BAGFS', 24.28, False]
# ['BAKAB', 40.94, False]
# ['BALAT', 37.7, False]
# ['BANVT', 312.75, False]
# ['BARMA', 18.57, False]
# ['BASCM', 11.5, False]
# ['BASGZ', 29.78, False]
# ['BAYRK', 26.24, False]
# ['BEGYO', 3.86, False]
# ['BERA', 17.14, False]
# ['BEYAZ', 27.3, False]
# ['BFREN', 805.0, False]
# ['BIENY', 33.56, False]
# ['BIGCH', 34.2, False]
# ['BIMAS', 588.0, False]
# ['BINHO', 461.25, False]
# ['BIOEN', 19.4, False]
# ['BIZIM', 38.86, False]
# ['BJKAS', 6.0, False]
# ['BLCYT', 24.1, False]
# ['BMSCH', 22.72, False]
# ['BMSTL', 49.94, False]
# ['BNTAS', 12.3, False]
# ['BOBET', 27.14, False]
# ['BORLS', 36.74, False]
# ['BORSK', 30.64, False]
# ['BOSSA', 17.2, False]
# ['BRISA', 106.9, False]
# ['BRKO', 9.19, False]
# ['BRKSN', 32.2, True]
# ['BRKVY', 50.9, False]
# ['BRLSM', 18.45, False]
# ['BRMEN', 6.43, False]
# ['BRSAN', 417.25, False]
# ['BRYAT', 2100.0, False]
# ['BSOKE', 46.22, False]
# ['BTCIM', 169.0, False]
# ['BUCIM', 8.13, False]
# ['BURCE', 190.7, True]
# ['BURVA', 114.0, False]
# ['BVSAN', 103.5, False]
# ['BYDNR', 27.62, False]
# ['CANTE', 1.86, False]
# ['CASA', 96.45, False]
# ['CATES', 56.6, False]
# ['CCOLA', 854.0, False]
# ['CELHA', 34.32, False]
# ['CEMAS', 4.26, False]
# ['CEMTS', 11.19, False]
# ['CEOEM', 32.8, False]
# ['CIMSA', 34.0, False]
# ['CLEBI', 2102.0, False]
# ['CMBTN', 2662.5, False]
# ['CMENT', 338.0, False]
# ['CONSE', 3.28, False]
# ['COSMO', 128.4, False]
# ['CRDFA', 7.58, False]
# ['CRFSA', 112.1, False]
# ['CUSAN', 22.9, False]
# ['CVKMD', 516.0, False]
# ['CWENE', 232.3, True]
# ['DAGHL', 16.86, False]
# ['DAGI', 9.35, False]
# ['DAPGM', 32.52, False]
# ['DARDL', 6.16, False]
# ['DCTTR', 18.63, False]
# ['DENGE', 6.84, False]
# ['DERHL', 11.29, False]
# ['DERIM', 39.2, False]
# ['DESA', 23.64, False]
# ['DESPC', 46.52, False]
# ['DEVA', 70.85, False]
# ['DGATE', 36.7, False]
# ['DGGYO', 30.56, False]
# ['DGNMO', 10.67, False]
# ['DIRIT', 51.6, False]
# ['DITAS', 25.7, False]
# ['DMRGD', 15.48, False]
# ['DMSAS', 5.62, False]
# ['DNISI', 13.52, False]
# ['DOAS', 237.9, False]
# ['DOBUR', 244.4, False]
# ['DOCO', 5417.5, False]
# ['DOFER', 37.0, False]
# ['DOGUB', 28.7, False]
# ['DOHOL', 16.8, False]
# ['DOKTA', 32.6, False]
# ['DURDO', 13.62, False]
# ['DYOBY', 61.8, False]
# ['DZGYO', 5.04, True]
# ['EBEBK', 44.22, False]
# ['ECILC', 54.9, False]
# ['ECZYT', 218.8, False]
# ['EDATA', 17.92, False]
# ['EDIP', 23.3, False]
# ['EFORC', 25.86, False]
# ['EGEEN', 11950.0, False]
# ['EGEPO', 21.2, False]
# ['EGGUB', 53.85, False]
# ['EGPRO', 193.1, True]
# ['EGSER', 4.01, False]
# ['EKGYO', 11.07, False]
# ['EKIZ', 71.0, False]
# ['EKOS', 37.64, False]
# ['EKSUN', 7.05, False]
# ['ELITE', 31.2, False]
# ['EMKEL', 14.45, False]
# ['EMNIS', 341.5, False]
# ['ENERY', 193.0, False]
# ['ENJSA', 67.05, False]
# ['ENKAI', 46.36, False]
# ['ENSRI', 19.78, False]
# ['ENTRA', 10.39, False]
# ['EPLAS', 7.05, False]
# ['ERBOS', 201.5, False]
# ['ERCB', 114.1, False]
# ['EREGL', 55.05, False]
# ['ERSU', 18.22, False]
# ['ESCAR', 365.75, False]
# ['ESCOM', 59.75, False]
# ['ESEN', 20.46, False]
# ['ETILR', 22.68, False]
# ['ETYAT', 13.3, False]
# ['EUHOL', 3.75, False]
# ['EUKYO', 17.47, False]
# ['EUPWR', 99.25, False]
# ['EUREN', 15.34, False]
# ['EUYO', 12.52, False]
# ['EYGYO', 9.8, False]
# ['FADE', 15.44, False]
# ['FENER', 141.0, False]
# ['FLAP', 10.08, False]
# ['FMIZP', 310.5, False]
# ['FONET', 22.28, True]
# ['FORMT', 3.49, False]
# ['FORTE', 60.75, False]
# ['FRIGO', 7.83, False]
# ['FROTO', 948.5, False]
# ['FZLGY', 12.5, False]
# ['GARAN', 124.2, False]
# ['GARFA', 22.88, False]
# ['GEDIK', 14.72, False]
# ['GEDZA', 22.46, False]
# ['GENIL', 72.5, False]
# ['GENTS', 9.56, False]
# ['GEREL', 32.46, False]
# ['GESAN', 49.3, False]
# ['GIPTA', 35.84, False]
# ['GLBMD', 36.24, False]
# ['GLCVY', 43.0, False]
# ['GLDTR', 224.1, False]
# ['GLRYH', 11.57, False]
# ['GLYHO', 16.32, False]
# ['GMSTR', 195.05, False]
# ['GMTAS', 9.72, False]
# ['GOKNR', 33.74, False]
# ['GOLTS', 479.0, False]
# ['GOODY', 19.5, False]
# ['GOZDE', 25.7, False]
# ['GRNYO', 9.16, False]
# ['GRSEL', 133.3, False]
# ['GRTRK', 79.7, False]
# ['GSDDE', 8.69, False]
# ['GSDHO', 3.92, False]
# ['GSRAY', 8.18, False]
# ['GUBRF', 168.5, False]
# ['GWIND', 31.96, False]
# ['GZNMI', 35.44, False]
# ['HALKB', 17.02, False]
# ['HATEK', 13.8, False]
# ['HATSN', 56.6, False]
# ['HDFGS', 1.85, False]
# ['HEDEF', 22.8, False]
# ['HEKTS', 12.12, False]
# ['HKTM', 18.59, False]
# ['HLGYO', 2.88, False]
# ['HOROZ', 57.2, False]
# ['HRKET', 87.5, False]
# ['HTTBT', 71.55, False]
# ['HUBVC', 11.09, False]
# ['HUNER', 3.78, False]
# ['HURGZ', 4.5, False]
# ['ICBCT', 15.0, False]
# ['ICUGS', 18.85, False]
# ['IDGYO', 6.52, False]
# ['IEYHO', 7.7, False]
# ['IHAAS', 24.34, False]
# ['IHEVA', 2.63, False]
# ['IHGZT', 1.37, False]
# ['IHLAS', 1.28, False]
# ['IHLGM', 1.46, False]
# ['IHYAY', 6.62, False]
# ['IMASM', 12.4, False]
# ['INDES', 8.32, False]
# ['INFO', 9.97, False]
# ['INGRM', 520.0, False]
# ['INTEK', 661.0, False]
# ['INTEM', 242.0, False]
# ['INVEO', 10.0, False]
# ['INVES', 344.0, False]
# ['IPEKE', 45.24, False]
# ['ISBIR', 118.0, False]
# ['ISBTR', 621000.0, False]
# ['ISCTR', 14.86, False]
# ['ISDMR', 37.86, False]
# ['ISFIN', 13.11, False]
# ['ISGLK', 274.5, False]
# ['ISGSY', 24.28, False]
# ['ISGYO', 16.06, True]
# ['ISKPL', 14.11, False]
# ['ISKUR', 6000000.0, False]
# ['ISMEN', 38.1, False]
# ['ISSEN', 12.0, True]
# ['ISYAT', 9.62, False]
# ['IZENR', 23.4, False]
# ['IZFAS', 58.6, False]
# ['IZINV', 65.8, False]
# ['IZMDC', 6.0, False]
# ['JANTS', 27.92, False]
# ['KAPLM', 202.3, False]
# ['KAREL', 15.07, False]
# ['KARSN', 15.02, False]
# ['KARTN', 99.95, False]
# ['KARYE', 30.28, False]
# ['KATMR', 3.61, False]
# ['KAYSE', 26.28, False]
# ['KBORU', 102.5, False]
# ['KCAER', 46.2, False]
# ['KCHOL', 208.8, False]
# ['KENT', 1125.0, False]
# ['KERVN', 2.14, False]
# ['KERVT', 16.5, False]
# ['KFEIN', 117.1, False]
# ['KGYO', 32.92, False]
# ['KIMMR', 9.92, False]
# ['KLGYO', 4.66, False]
# ['KLKIM', 27.94, False]
# ['KLMSN', 28.82, False]
# ['KLNMA', 15.0, False]
# ['KLRHO', 33.3, False]
# ['KLSER', 48.5, False]
# ['KLSYN', 5.37, False]
# ['KMPUR', 53.15, False]
# ['KNFRT', 11.41, False]
# ['KOCMT', 18.62, False]
# ['KONKA', 46.68, False]
# ['KONTR', 59.5, False]
# ['KONYA', 7525.0, False]
# ['KOPOL', 51.5, False]
# ['KORDS', 97.4, False]
# ['KOTON', 23.38, False]
# ['KOZAA', 64.5, False]
# ['KOZAL', 24.3, False]
# ['KRDMA', 22.9, False]
# ['KRDMB', 21.14, False]
# ['KRDMD', 29.34, False]
# ['KRGYO', 30.1, False]
# ['KRONT', 22.44, False]
# ['KRPLS', 7.96, False]
# ['KRSTL', 6.93, False]
# ['KRTEK', 29.7, False]
# ['KRVGD', 3.09, False]
# ['KSTUR', 4500.0, False]
# ['KTLEV', 41.52, False]
# ['KTSKR', 75.95, False]
# ['KUTPO', 81.65, False]
# ['KUVVA', 46.96, False]
# ['KUYAS', 53.45, False]
# ['KZBGY', 25.16, False]
# ['KZGYO', 21.44, False]
# ['LIDER', 78.0, False]
# ['LIDFA', 8.06, False]
# ['LILAK', 30.18, False]
# ['LINK', 660.0, False]
# ['LKMNH', 96.15, False]
# ['LMKDC', 26.5, False]
# ['LOGO', 118.3, False]
# ['LRSHO', 2.93, False]
# ['LUKSK', 104.5, False]
# ['LYDHO', 138.5, False]
# ['MAALT', 874.5, False]
# ['MACKO', 93.1, False]
# ['MAGEN', 22.1, False]
# ['MAKIM', 29.68, False]
# ['MAKTK', 8.24, False]
# ['MANAS', 13.1, False]
# ['MARBL', 15.88, False]
# ['MARKA', 75.0, False]
# ['MARTI', 3.63, False]
# ['MAVI', 109.4, False]
# ['MEDTR', 36.96, False]
# ['MEGAP', 7.51, False]
# ['MEGMT', 40.38, False]
# ['MEKAG', 56.6, False]
# ['MEPET', 10.38, False]
# ['MERCN', 12.36, False]
# ['MERIT', 206.0, False]
# ['MERKO', 10.9, False]
# ['METRO', 2.63, False]
# ['METUR', 12.77, False]
# ['MGROS', 543.0, False]
# ['MHRGY', 4.76, False]
# ['MIATK', 58.5, True]
# ['MMCAS', 29.7, False]
# ['MNDRS', 12.4, False]
# ['MNDTR', 6.64, False]
# ['MOBTL', 5.2, False]
# ['MOGAN', 14.05, False]
# ['MPARK', 371.0, False]
# ['MPATA', 3399.0, False]
# ['MRGYO', 5.63, False]
# ['MRSHL', 1800.0, False]
# ['MSGYO', 12.7, False]
# ['MTRKS', 46.9, False]
# ['MTRYO', 11.4, False]
# ['MZHLD', 7.88, False]
# ['NATEN', 49.16, False]
# ['NETAS', 66.8, False]
# ['NIBAS', 16.72, False]
# ['NTGAZ', 5.91, False]
# ['NTHOL', 35.86, False]
# ['NUGYO', 8.45, False]
# ['NUHCM', 290.25, False]
# ['OBAMS', 39.08, False]
# ['OBASE', 40.3, False]
# ['ODAS', 8.25, False]
# ['ODINE', 103.5, False]
# ['OFSYM', 42.08, False]
# ['ONCSM', 143.5, False]
# ['ONRYT', 105.5, False]
# ['OPX30', 57.66, False]
# ['ORCAY', 11.49, False]
# ['ORGE', 72.45, False]
# ['ORMA', 218.0, False]
# ['OSMEN', 279.0, False]
# ['OSTIM', 6.77, True]
# ['OTKAR', 577.5, False]
# ['OTTO', 299.75, False]
# ['OYAKC', 75.05, False]
# ['OYAYO', 33.94, False]
# ['OYLUM', 10.01, False]
# ['OYYAT', 43.04, False]
# ['OZGYO', 5.66, False]
# ['OZKGY', 10.95, False]
# ['OZRDN', 43.76, False]
# ['OZSUB', 38.5, False]
# ['OZYSR', 31.28, False]
# ['PAGYO', 51.0, False]
# ['PAMEL', 117.9, False]
# ['PAPIL', 140.8, False]
# ['PARSN', 111.1, False]
# ['PASEU', 77.45, False]
# ['PATEK', 99.5, False]
# ['PCILT', 15.37, False]
# ['PEHOL', 31.42, False]
# ERROR:tvDatafeed.main:Connection to remote host was lost.
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# ['PENGD', 7.71, False]
# ['PENTA', 16.18, False]
# ['PETKM', 23.24, False]
# ['PETUN', 84.15, False]
# ['PGSUS', 232.0, False]
# ['PINSU', 23.78, False]
# ['PKART', 81.75, False]
# ['PKENT', 240.4, False]
# ['PLTUR', 25.74, False]
# ['PNLSN', 61.25, False]
# ['PNSUT', 85.2, False]
# ['POLHO', 13.53, False]
# ['POLTK', 7932.5, False]
# ['PRDGS', 6.47, False]
# ['PRKAB', 35.86, False]
# ['PRKME', 22.38, False]
# ['PRZMA', 36.7, False]
# ['PSDTC', 90.0, False]
# ['PSGYO', 1.95, False]
# ['QNBFB', 286.5, False]
# ['QNBFL', 113.0, False]
# ['QPERP', 6045.0, False]
# ['QTEMZ', 333.3, False]
# ['QUAGR', 3.21, False]
# ['RALYH', 228.2, False]
# ['RAYSG', 511.5, False]
# ['REEDR', 36.36, False]
# ['RGYAS', 115.1, False]
# ['RNPOL', 28.8, False]
# ['RODRG', 27.0, True]
# ['RPAVS', 6011.0, False]
# ['RPFGY', 5497.0, False]
# ['RTALB', 11.65, False]
# ['RUBNS', 31.4, False]
# ['RYGYO', 11.53, False]
# ['RYSAS', 49.46, False]
# ['SAFKR', 54.75, False]
# ['SAHOL', 95.15, False]
# ['SAMAT', 42.2, False]
# ['SANEL', 28.7, False]
# ['SANFM', 80.3, False]
# ['SANKO', 26.86, False]
# ['SARKY', 33.28, False]
# ['SASA', 46.64, False]
# ['SAYAS', 63.6, False]
# ['SDTTR', 294.5, False]
# ['SEGMN', 26.22, False]
# ['SEGYO', 4.33, False]
# ['SEKFK', 10.19, True]
# ['SEKUR', 12.7, False]
# ['SELEC', 58.1, False]
# ['SELGD', 53.0, False]
# ['SELVA', 13.98, False]
# ['SEYKM', 9.66, False]
# ['SILVR', 20.46, False]
# ['SISE', 46.48, False]
# ['SKBNK', 4.28, False]
# ['SKTAS', 5.45, False]
# ['SKYLP', 112.2, False]
# ['SKYMD', 11.44, False]
# ['SMART', 35.94, False]
# ['SMRTG', 49.22, False]
# ['SNGYO', 7.1, False]
# ['SNICA', 6.88, False]
# ['SNKRN', 70.1, False]
# ['SNPAM', 75.6, False]
# ['SODSN', 150.1, False]
# ['SOKE', 14.08, False]
# ['SOKM', 60.45, False]
# ['SONME', 90.0, False]
# ['SRVGY', 349.75, False]
# ['SUMAS', 376.0, False]
# ['SUNTK', 19.32, False]
# ['SURGY', 58.45, False]
# ['SUWEN', 33.06, False]
# ['TABGD', 180.0, False]
# ['TARKM', 510.0, False]
# ['TATEN', 36.5, False]
# ['TATGD', 26.94, False]
# ['TAVHL', 263.5, False]
# ['TBORG', 105.9, False]
# ['TCELL', 102.5, False]
# ['TDGYO', 10.88, False]
# ['TEKTU', 5.57, False]
# ['TERA', 14.7, False]
# ['TETMT', 13900.0, False]
# ['TEZOL', 17.4, False]
# ['TGSAS', 69.3, False]
# ['THYAO', 291.5, False]
# ['TKFEN', 55.6, False]
# ['TKNSA', 31.34, False]
# ['TLMAN', 105.3, False]
# ['TMPOL', 76.1, False]
# ['TMSN', 129.4, False]
# ['TNZTP', 61.75, False]
# ['TOASO', 261.5, False]
# ['TRCAS', 27.32, False]
# ['TRGYO', 50.1, False]
# ['TRILC', 25.06, False]
# ['TSGYO', 13.2, False]
# ['TSKB', 12.25, False]
# ['TSPOR', 2.44, False]
# ['TTKOM', 50.0, False]
# ['TTRAK', 762.0, False]
# ['TUCLK', 11.74, False]
# ['TUKAS', 9.08, False]
# ['TUPRS', 159.1, False]
# ['TUREX', 77.5, False]
# ['TURGG', 619.5, False]
# ['TURSG', 58.7, False]
# ['UFUK', 660.0, False]
# ['ULAS', 24.0, False]
# ['ULKER', 172.4, False]
# ['ULUFA', 13.64, True]
# ['ULUSE', 174.4, False]
# ['ULUUN', 29.92, False]
# ['UMPAS', 13.1, False]
# ['UNLU', 16.18, False]
# ['USAK', 24.42, False]
# ['USDTR', 3115.0, False]
# ['VAKBN', 20.12, False]
# ['VAKFN', 2.97, False]
# ['VAKKO', 117.1, False]
# ['VANGD', 19.35, False]
# ['VBTYZ', 31.06, False]
# ['VERTU', 43.68, False]
# ['VERUS', 316.0, False]
# ['VESBE', 20.06, False]
# ['VESTL', 71.4, False]
# ['VKFYO', 21.8, False]
# ['VKGYO', 1.98, False]
# ['VKING', 50.05, False]
# ['VRGYO', 3.96, False]
# ['YAPRK', 409.25, False]
# ['YATAS', 30.9, False]
# ['YAYLA', 16.8, False]
# ['YBTAS', 147700.0, False]
# ['YEOTK', 209.5, True]
# ['YESIL', 4.45, False]
# ['YGGYO', 49.52, False]
# ['YGYO', 12.36, False]
# ['YIGIT', 47.16, False]
# ['YKBNK', 31.2, False]
# ['YKSLN', 9.94, False]
# ['YONGA', 82.0, False]
# ['YUNSA', 77.5, False]
# ['YYAPI', 5.88, False]
# ['YYLGD', 12.9, False]
# ['Z30EA', 137.8, False]
# ['Z30KE', 104.15, False]
# ['Z30KP', 149.7, False]
# ['ZEDUR', 10.79, False]
# ['ZELOT', 109.5, False]
# ['ZGOLD', 277.5, False]
# ['ZOREN', 5.45, False]
# ['ZPBDL', 155.85, False]
# ['ZPLIB', 165.6, False]
# ['ZPT10', 84.0, False]
# ['ZPX30', 148.45, False]
# ['ZRE20', 121.5, False]
# ['ZRGYO', 7.11, False]
# ['ZSR25', 39.39, False]
# ['ZTM15', 148.55, False]
#     Hisse Adı  Son Fiyat  Dip Sinyali
# 15      AKFGY       2.30         True
# 19       AKSA      10.16         True
# 21      AKSGY      19.90         True
# 48      APYMD    2590.00         True
# 51      ARCLK     160.70         True
# 53      ARENA      39.64         True
# 107     BRKSN      32.20         True
# 116     BURCE     190.70         True
# 138     CWENE     232.30         True
# 167     DZGYO       5.04         True
# 177     EGPRO     193.10         True
# 211     FONET      22.28         True
# 286     ISGYO      16.06         True
# 290     ISSEN      12.00         True
# 380     MIATK      58.50         True
# 413     OSTIM       6.77         True
# 462     RODRG      27.00         True
# 481     SEKFK      10.19         True
# 546     ULUFA      13.64         True
# 570     YEOTK     209.50         True
